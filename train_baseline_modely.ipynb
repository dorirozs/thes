# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, classification_report
from xgboost import XGBClassifier

df = pd.read_csv('wesad_processed_features.csv')

# Drop NaN columns
df = df.dropna(axis=1, how='all')
# Fill NaNs with the mean or zero
df = df.fillna(0)

ecg_features = [c for c in df.columns if 'HRV' in c or 'ECG_Rate' in c]
gsr_features = [c for c in df.columns if 'SCR' in c or 'EDA' in c]
fusion_features = ecg_features + gsr_features

# Convert labels to 0 (Baseline) and 1 (Stress) for XGBoost
# 1=Baseline, 2=Stress
y = df['label'].map({1: 0, 2: 1})
